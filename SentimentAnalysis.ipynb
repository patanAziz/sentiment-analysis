# %% [markdown]
# <a href="https://colab.research.google.com/github/patanAziz/sentiment-analysis/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle -q

# %%
import os
import zipfile
import json
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
kaggle_confiq = json.load(open('/content/kaggle (1).json'))

# %%
kaggle_confiq.keys()
# Out:
# dict_keys(['username', 'key'])

# %%
os.environ["KAGGLE_USERNAME"] = kaggle_confiq['username']
os.environ["KAGGLE_KEY"] = kaggle_confiq['key']

# %%
# !kaggle datasets download kazanova/sentiment140
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kazanova/sentiment140
# License(s): other
# ...
#  65% 53.0M/80.9M [00:00<00:00, 277MB/s]
# 100% 80.9M/80.9M [00:00<00:00, 285MB/s]

# %%
# !ls
# Out:
# 'kaggle (1).json'   sample_data   sentiment140.zip

# %%
with zipfile.ZipFile("/content/sentiment140.zip",'r') as zip:
  zip.extractall()

# %%
# !ls
# Out:
# 'kaggle (1).json'   sentiment140.zip
#  sample_data	    training.1600000.processed.noemoticon.csv

# %%
df = pd.read_csv(
    '/content/training.1600000.processed.noemoticon.csv',
    encoding='ISO-8859-1',
    header=None,
    names=['sentiment', 'id', 'date', 'query', 'user', 'text']
)

# %%
df.head()
# Out:
#    sentiment  ...                                               text
# 0          0  ...  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  ...  is upset that he can't update his Facebook by ...
# 2          0  ...  @Kenichan I dived many times for the ball. Man...
# 3          0  ...    my whole body feels itchy and like its on fire
# 4          0  ...  @nationwideclass no, it's not behaving at all....
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %%
df['sentiment'] = df['sentiment'].map({0:0,4:1})

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# 0    800000
# 1    800000
# Name: count, dtype: int64

# %%
df['sentiment'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum()
# Out:
# sentiment    0
# id           0
# date         0
# query        0
# user         0
# text         0
# dtype: int64

# %%
df['text']
# Out:
# 0          @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          is upset that he can't update his Facebook by ...
# 2          @Kenichan I dived many times for the ball. Man...
# 3            my whole body feels itchy and like its on fire
# 4          @nationwideclass no, it's not behaving at all....
#                                  ...
# 1599995    Just woke up. Having no school is the best fee...
# 1599996    TheWDB.com - Very cool to hear old Walt interv...
# 1599997    Are you ready for your MoJo Makeover? Ask me f...
# 1599998    Happy 38th Birthday to my boo of alll time!!! ...
# 1599999    happy #charitytuesday @theNSPCC @SparksCharity...
# Name: text, Length: 1600000, dtype: object

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df['text']
# Out:
# 0          @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          is upset that he can't update his Facebook by ...
# 2          @Kenichan I dived many times for the ball. Man...
# 3            my whole body feels itchy and like its on fire
# 4          @nationwideclass no, it's not behaving at all....
#                                  ...
# 1599995    Just woke up. Having no school is the best fee...
# 1599996    TheWDB.com - Very cool to hear old Walt interv...
# 1599997    Are you ready for your MoJo Makeover? Ask me f...
# 1599998    Happy 38th Birthday to my boo of alll time!!! ...
# 1599999    happy #charitytuesday @theNSPCC @SparksCharity...
# Name: text, Length: 1600000, dtype: object

# %%
stemmer = PorterStemmer()
def stemming(text):
  text = re.sub('[^a-zA-Z]\s', '' ,text)
  text = text.lower()
  tokens= text.split()
  tokens = [stemmer.stem(word) for word in tokens if word not in stopwords.words('english')]
  tokens = " ".join(tokens)
  return tokens

# %%
df.head()
# Out:
#    sentiment  ...                                               text
# 0          0  ...  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  ...  is upset that he can't update his Facebook by ...
# 2          0  ...  @Kenichan I dived many times for the ball. Man...
# 3          0  ...    my whole body feels itchy and like its on fire
# 4          0  ...  @nationwideclass no, it's not behaving at all....
#
# [5 rows x 6 columns]

# %%
df['stemmed_content'] = df['text'].apply(stemming)

# %%
df.head()
# Out:
#    sentiment  ...                                    stemmed_content
# 0          0  ...  @switchfoot http://twitpic.com/2y1zl awwwthat'...
# 1          0  ...  upset can't updat facebook text it..and might ...
# 2          0  ...  @kenichan dive mani time ballmanag save 50 res...
# 3          0  ...                    whole bodi feel itchi like fire
# 4          0  ...  @nationwideclass noit' behav alli'm madwhi her...
#
# [5 rows x 7 columns]

# %%
X = df['stemmed_content']
y = df['sentiment']

x_train , x_test ,y_train , y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=2)

# %%
y_test[1142114]
# Out:
# np.int64(1)

# %%
vectorizer = TfidfVectorizer()

# %%
x_train = vectorizer.fit_transform(x_train)
x_test = vectorizer.transform(x_test)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prectic_x = model.predict(x_train)
accuracy = accuracy_score(y_train,prectic_x)

# %%
accuracy*100
# Out:
# 81.15375

# %%
import pickle

# %%
file_name = 'Trained_model.sav'
pickle.dump(model,open(file_name,'wb'))

# %%
loaded_model = pickle.load(open('/content/Trained_model.sav','rb'))

# %%
data_ = x_test[200]

# %%
data_
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9 stored elements and shape (1, 1152539)>

# %%
prediction1 =  loaded_model.predict(data_)

# %%
if (int(prediction1[0])==1):
  print("Positive")
else:
  print("Negative")
# Out:
# Positive
